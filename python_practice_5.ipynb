# %% [markdown]
# # I. OOP

# %% [markdown]
# 1. (6б). Створіть клас Building, додайте три атрибути, один з яких має значення за замовчуванням та два методи на свій розсуд.

# %%
class Building:
  def __init__(self, location, floors, type="Office"):
    self.location = location
    self.floors = floors
    self.type = type

  def destroy(self):
    self.floors = 0
    print(f"{self.type} at location {self.location} has been destroyed")

  def is_dormitory(self):
    if self.type == "Dormitory":
      print("This building is indeed dormitory")
    else:
      print("This building is not dormitory")

# %% [markdown]
# 2. (2б). Створіть два обʼєкти цього класу, де один з обʼєктів створюється із дефолтним значенням атрибуту. На одному обʼєкті отримайте значення його атрибуту, а на іншому викличте один з його методів.

# %%
dormitory = Building("Ekster 14-B", 9, "Dormitory")
office = Building("Somewhere 15-A", 16)

print(f"Dormitory's address is {dormitory.location}")

office.destroy()
# Out:
# Dormitory's address is Ekster 14-B
# Office at location Somewhere 15-A has been destroyed

# %% [markdown]
# 3. (5б). Створіть клас, де атрибути мають різні рівні доступу. Спробуйте отримати їхні значення та опишіть результати.

# %%
class BuildingAccessLevels:
  def __init__(self, location = "Somewhere", floors = 6, type="Office"):
    self.location = location
    self._floors = floors
    self.__type = type

building = BuildingAccessLevels()
print(f"{building.location} is public and should be printed")
print(f"{building._floors} is protected and should be printed too")
try:
  print(f"{building.__type} is private and should throw error")
except AttributeError as e:
  print(f"Printing private attribute threw error: {e}")
# Out:
# Somewhere is public and should be printed
# 6 is protected and should be printed too
# Printing private attribute threw error: 'BuildingAccessLevels' object has no attribute '__type'

# %% [markdown]
# 4. (7б). Як ви розумієте термін self? Для чого використовується метод __init __?

# %% [markdown]
# *   self - посилання на той екземпляр класу, в якому виконується виклик self
# *   init - метод, що створює обʼєкт класу, опціонально ініціалізує атрибути обʼєкту

# %% [markdown]
# 5. (9б). Створіть клас 3D-фігура без атрибутів, з методом get_volume для отримання об'єму фігури, що повертає 0 та __add __, який приймає self та other в якості аргументів, а повертає суму об'ємів 3d-фігур self та other.

# %%
class Figure:
  def get_volume(self):
    return 0

  def __add__(self, other):
    if isinstance(other, Figure):
      return self.get_volume() + other.get_volume()
    return NotImplemented

# %% [markdown]
# 6. (11б). Створіть 2 дочірніх класи від 3d-фігура: Циліндр та Куб, які мають атрибути, необхідні для розрахунку об'єму. Визначте метод get_volume в кожному з них так, щоби вони розраховували об'єм у залежності від формули для кожного типу фігури. Створіть обʼєкт класу Циліндр та обʼєкт класу Куб. Виконайте операцію суми за допомогою оператора + між ними, аби знайти сумарний об'єм.

# %%
import math

class Cylinder(Figure):
  def __init__(self, radius, height):
      self.radius = radius
      self.height = height

  def get_volume(self):
      return math.pi * (self.radius ** 2) * self.height

class Cube(Figure):
  def __init__(self, side):
      self.side = side

  def get_volume(self):
      return self.side ** 3

cylinder = Cylinder(3, 10)
cube = Cube(5)

print(f"Sum: {cylinder + cube}")
# Out:
# Sum: 407.7433388230814

# %% [markdown]
# 7. (3б). Продемонструйте різницю між isinstance та issubclass.

# %%
print(f"isinstance(cylinder, Figure): {isinstance(cylinder, Figure)}")
print(f"isinstance(cylinder, Cylinder): {isinstance(cylinder, Cylinder)}")
print(f"isinstance(cylinder, Cube): {isinstance(cylinder, Cube)}\n")
print(f"issubclass(Cylinder, Figure): {issubclass(Cylinder, Figure)}")
print(f"issubclass(Cylinder, Cylinder): {issubclass(Cylinder, Cylinder)}")
print(f"issubclass(Cylinder, Cube): {issubclass(Cylinder, Cube)}")
# Out:
# isinstance(cylinder, Figure): True
# isinstance(cylinder, Cylinder): True
# isinstance(cylinder, Cube): False
#
# issubclass(Cylinder, Figure): True
# issubclass(Cylinder, Cylinder): True
# issubclass(Cylinder, Cube): False

# %% [markdown]
# 8. (13б). Створіть клас EWallet з приватними атрибутами balance та id. Реалізуйте методи поповнення та зняття коштів, забезпечивши належну інкапсуляцію. Підказка: використовуйте декоратори property та setter.

# %%
class InsufficientFundsError(Exception):
  def __init__(self, current_balance, attempted_withdrawal):
    self.current_balance = current_balance
    self.attempted_withdrawal = attempted_withdrawal
    super().__init__(f"Insufficient funds. Cannot withdraw {attempted_withdrawal}. Current balance is {current_balance}.")

class InvalidAmount(Exception):
  def __init__(self):
    super().__init__(f"Invalid amount")

class EWallet:
  def __init__(self, id, balance=0):
    self.__id = id
    self.__balance = balance

  @property
  def balance(self):
    return self.__balance

  @balance.setter
  def balance(self, amount):
    if amount >= 0:
      self.__balance = amount
    else:
      raise InvalidAmount

  def deposit(self, amount):
    if amount > 0:
      self.__balance += amount
    else:
      raise InvalidAmount

  def withdraw(self, amount):
    if amount < 0:
      raise InvalidAmount
    if amount > self.__balance:
      raise InsufficientFundsError(self.__balance, amount)
    self.__balance -= amount

# %% [markdown]
# 9. (11б). Створіть клас ShoppingCart, який містить список об'єктів типу Item. Реалізуйте методи для додавання айтемів, їх видалення та відображення списку айтемів.

# %%
class Item:
  def __init__(self, name, price, quantity = 1):
    self.name = name
    self.quantity = quantity
    self.price = price

  def __repr__(self):
    return f"{self.name} x{self.quantity}: {self.price * self.quantity} UAH"

class ShoppingCart:
  def __init__(self):
    self.items = []

  def add_item(self, name, price, quantity=1):
    for item in self.items:
      if item.name == name:
        item.quantity += quantity
        return
    self.items.append(Item(name, price, quantity))

  def remove_item(self, item_name, quantity=None):
    for item in self.items:
      if item.name == item_name:
        if quantity is None:
          self.items.remove(item)
        else:
          item.quantity -= quantity
          if item.quantity <= 0:
            self.items.remove(item)
        return

  def show_items(self):
    print("Items in cart:")
    for item in self.items:
      print(f"- {item}")

# %% [markdown]
# 10. (13б). Створіть клас Vehicle з атрибутами brand (manufacturer) та production_age. Створіть ще один клас Engine з такими атрибутами, як type (ex. petrol) та size (volume, litres). Створіть клас Car, який успадковує обидва класи Vehicle та Engine. Продемонструйте використання множинної спадковості, створивши обʼєкт класу Car та отримавши mro для цього класу.

# %%
class Vehicle:
  def __init__(self, manufacturer, production_age):
    self.manufacturer = manufacturer
    self.production_age = production_age

class Engine:
  def __init__(self, engine_type, engine_volume):
    self.engine_type = engine_type
    self.engine_volume = engine_volume

class Car(Vehicle, Engine):
  def __init__(self, manufacturer, production_age, engine_type, engine_volume):
    Vehicle.__init__(self, manufacturer, production_age)
    Engine.__init__(self, engine_type, engine_volume)

car = Car("Mazda", 2020, "Petrol", 2.0)
print(Car.mro())
# Out:
# [<class '__main__.Car'>, <class '__main__.Vehicle'>, <class '__main__.Engine'>, <class 'object'>]

# %% [markdown]
# # II. Iterator

# %% [markdown]
# 11. (4б). Визначте рядок(str) з 4ма різними за значенням символами. Створіть ітератор на основі цього рядка. Викличте 5 разів функцію next на ітераторі, 4ри перших з них огорніть у ф-цію print().

# %%
str = "abcd"
iterator = iter(str)

print(next(iterator))
print(next(iterator))
print(next(iterator))
print(next(iterator))
try:
  next(iterator)
except StopIteration:
  print(f"5th call resulted in StopIteration")
# Out:
# a
# b
# c
# d
# 5th call resulted in StopIteration

# %% [markdown]
# А що якщо викликати цю ж функцію на рядку?

# %%
str = "abcd"
try:
  print(next(str))
except TypeError as e:
  print(f"Error: {e}")
# Out:
# Error: 'str' object is not an iterator

# %% [markdown]
#  12. (5б). Опишіть своїми словами в одному реченні, як ви розумієте різницю між ітерабельними обʼєктами та ітераторами (можна на прикладі).

# %% [markdown]
# *   Ітерабельний обʼєкт - обʼєкт, на якому можна викликати ітератор
# *   Ітератор - обʼєкт, який ітерує ітерабельний обʼєкт за допомогою викликів next()

# %% [markdown]
# 13. (11б). Створіть клас, що має визначений Iterator Protocol та при кожному виклику next повертає назву дня тижня, поки вони не вичерпаються. Зверніть увагу, що порядок має значення.

# %%
class DaysIterator:
  def __init__(self):
    self.days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
    self.index = 0

  def __iter__(self):
    return self

  def __next__(self):
    if self.index < len(self.days):
      day = self.days[self.index]
      self.index += 1
      return day
    else:
      raise StopIteration

days = DaysIterator()
for day in days:
  print(day)
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# # Вітаю! Ви велика(ий) молодець, що впоралась(вся). Похваліть себе та побалуйте чимось приємним. Я Вами пишаюся.
